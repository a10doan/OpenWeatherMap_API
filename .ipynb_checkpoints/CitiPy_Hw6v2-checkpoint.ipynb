# %% [markdown]
# #### Analysis #1:
# Looking at the Temp vs. Latitude graph.  One noteable trend is that the temperature goes up towards the equator (latitude of 0).  And then decreases on either side.  This would suggest that it is hotter in the middle of the planet.  Possibly due to the fact that the equator receives the most light from the sun.  Hence the trend in the graph.

# %% [markdown]
# #### Analysis #2:
# Looking at the cloudiness and wind data, there are no noticeable changes in weather with change in latitude.  What we do notice though, is that the clusters of dots as we get closer to the 30-40 degree latitudes.  This would suggest that there are more data points at this range due to the amount of land mass focused in this latitude range.  Due to this uneven distrubution of land mass, most (if not all) of the data could be potentially biased and/or skewed.

# %% [markdown]
# #### Analysis #3:
# Looking at the Humidity vs. Latitude chart, there is no noticeable  relation between latitude and humidity.  Which suggest that there are other factors that should be considered when determining humidity.  Which leads to suggest that maybe ocean current has more affect on humidity that does latitude.  Although our analysis doesn't show a clear relation and/or concolusion, it can also lend support for other hypotheses and further research.

# %%
import json
import pandas as pd
import numpy as np
from citipy import citipy
from random import randint
from datetime import datetime
import matplotlib.pyplot as plt
import requests as req
import time
import os
import seaborn as sns
import apikeys

# %% [markdown]
# ### Collecting random cities - Applying CitiPy
# Used random number generator to generated random numbers between lat/long coordinates.  Numbers are then applied to citipy to find the nearest city to random coordinates, citipy uses kdtree to locate the nearest city.  Citipy takes in lat/long coordinates and locates the nearest city based on the coordinates.  Citipy returns city and country.  Return values are then placed in a tuple (used to compare BOTH city and country) then appended to a list, the function is set in a while-loop with an if-statement.  Reason behind this is to eliminate the possibility of cities having the same name but are in different countries.  Hence, with a tuple, both values can be compared and then added if it is not already in the list.

# %%
combined_list = []

while len(combined_list) < 510:
    lat_range = randint(-90,90)
    lng_range = randint(-180, 180)
    city = citipy.nearest_city(lat_range, lng_range)
    city_name = city.city_name
    country_name = city.country_code
    combined_ = (city_name, country_name) #'combined' is a tuple, used to compare BOTH city,country (in case of same city names, but different countries)
    if combined_ not in combined_list:
        combined_list.append(combined_)

# %% [markdown]
# ### Setting list of cities - Unzipping into two lists
# List of tuples (city, country) was used to compare and prevent same cities from being added to the list.  Now it is pulled apart into two lists (unzipped), later it will be used to set the columns for the dataframe (city, country).

# %%
city_list, country_list = zip(*combined_list)
city_list = list(city_list)
country_list = list(country_list)

# %% [markdown]
# ### Creating search parameters for OWM // Storing returned information into lists (ie. Temps, Clouds, Humidity) // Printing status update on process
# First, I set the usual parameters (api key and url), but then I use a UNIX timestamp to get past data.  In this case, it will be July 27, 2017 at approximately 2pm, because the data **must be consistent to the same hour within a day**.  Otherwise, if data was collected based on current data, then other time zones will be in different parts of the day, and it would skew the data.
# Second, I looped through the list of tuples with city names and country names (combined_list).  Then used each city and country as a parameter to be searched through OWM.  Then those names would be used to print status updates.
# Third, the try-except conditional was used instead of if-else for simplicity purposes.  An if-else could be used, if going that route, a 'response[200]' can be checked under the if-statement.  The except part, will append 'none' to the dataframe, OWM will not have weather on all cities, hence the error will notify the user with a print statement.  A counter ('number') is used to count the number of cities.

# %%
url = "http://api.openweathermap.org/data/2.5/weather"
api_key = apikeys.OWM_key

time_str1 = "Jul 27 13:50:06 +0000 2017"

converted_time1 = datetime.strptime(time_str1,
                                    "%b %d %H:%M:%S %z %Y")

start_unixtime = str(int(time.mktime(converted_time1.timetuple())))

lat_data = []
lng_data = []
temp_data = []
humid_data = []
cloud_data = []
wind_data = []
number = 1
for each_city, each_country in combined_list:
    print("Collecting data on city #" + str(number) + ': ' + str(each_city) + ', ' + str(each_country))
    try:
        params = {'appid': api_key,
                  'q': each_city + ',' + each_country,
                  'type': 'hour',
                  'start': start_unixtime,
                  'cnt': 1,
                  'units': 'metric'}
    
        weather_response = req.get(url, params)
        print("Requested URL: " + str(weather_response.url))
        weather_json = weather_response.json()
        lat_data.append(weather_json['coord']['lat'])
        lng_data.append(weather_json['coord']['lat'])
        temp_data.append(weather_json['main']['temp'])
        humid_data.append(weather_json['main']['humidity'])
        cloud_data.append(weather_json['clouds']['all'])
        wind_data.append(weather_json['wind']['speed'])
    except:
        print("OpenWeather has no information on city, appending NaN to " + str(each_city) + ", " + str(each_country))
        lat_data.append(None)
        lng_data.append(None)
        temp_data.append(None)
        humid_data.append(None)
        cloud_data.append(None)
        wind_data.append(None)
    number += 1
    
## print(json.dumps(weather_json, indent=4, sort_keys=True))
## print(lat_data)
## print(temp_data)
## print(humid_data)
## print(cloud_data)
## print(wind_data)
# Out:
# Collecting data on city #1: mirzapur, bd
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mirzapur%2Cbd&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #2: sentyabrskiy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sentyabrskiy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to sentyabrskiy, ru
# Collecting data on city #3: savalou, bj
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=savalou%2Cbj&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #4: taolanaro, mg
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=taolanaro%2Cmg&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to taolanaro, mg
# Collecting data on city #5: tiksi, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tiksi%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #6: birjand, ir
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=birjand%2Cir&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #7: albany, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=albany%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #8: busselton, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=busselton%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #9: khatanga, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=khatanga%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #10: rio gallegos, ar
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=rio+gallegos%2Car&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #11: maceio, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=maceio%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #12: tasiilaq, gl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tasiilaq%2Cgl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #13: puerto ayora, ec
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=puerto+ayora%2Cec&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #14: iaciara, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=iaciara%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #15: new norfolk, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=new+norfolk%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #16: hobart, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hobart%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #17: rikitea, pf
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=rikitea%2Cpf&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #18: cabo san lucas, mx
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=cabo+san+lucas%2Cmx&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #19: vaini, to
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vaini%2Cto&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #20: chokurdakh, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=chokurdakh%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #21: grindavik, is
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=grindavik%2Cis&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #22: yellowknife, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=yellowknife%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #23: saskylakh, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=saskylakh%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #24: copacabana, bo
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=copacabana%2Cbo&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to copacabana, bo
# Collecting data on city #25: leningradskiy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=leningradskiy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #26: sao filipe, cv
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sao+filipe%2Ccv&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #27: nome, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=nome%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to nome, us
# Collecting data on city #28: tuktoyaktuk, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tuktoyaktuk%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #29: pangnirtung, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=pangnirtung%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #30: nizamabad, in
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=nizamabad%2Cin&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #31: ribeira grande, pt
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ribeira+grande%2Cpt&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #32: kaeo, nz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kaeo%2Cnz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #33: nikolskoye, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=nikolskoye%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to nikolskoye, ru
# Collecting data on city #34: polunochnoye, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=polunochnoye%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #35: grand river south east, mu
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=grand+river+south+east%2Cmu&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to grand river south east, mu
# Collecting data on city #36: los llanos de aridane, es
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=los+llanos+de+aridane%2Ces&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #37: uri, in
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=uri%2Cin&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #38: bafq, ir
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bafq%2Cir&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #39: tazovskiy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tazovskiy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #40: san juan, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=san+juan%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #41: camacha, pt
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=camacha%2Cpt&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #42: cerveteri, it
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=cerveteri%2Cit&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #43: kapaa, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kapaa%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #44: imuris, mx
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=imuris%2Cmx&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #45: saldanha, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=saldanha%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #46: ostrovnoy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ostrovnoy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #47: barentsburg, sj
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=barentsburg%2Csj&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to barentsburg, sj
# Collecting data on city #48: basco, ph
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=basco%2Cph&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #49: saint-philippe, re
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=saint-philippe%2Cre&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #50: mataura, pf
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mataura%2Cpf&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to mataura, pf
# Collecting data on city #51: kirakira, sb
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kirakira%2Csb&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #52: illoqqortoormiut, gl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=illoqqortoormiut%2Cgl&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to illoqqortoormiut, gl
# Collecting data on city #53: saleaula, ws
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=saleaula%2Cws&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to saleaula, ws
# Collecting data on city #54: ust-nera, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ust-nera%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #55: gornopravdinsk, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=gornopravdinsk%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #56: iqaluit, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=iqaluit%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #57: shaunavon, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=shaunavon%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #58: tarabuco, bo
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tarabuco%2Cbo&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #59: warqla, dz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=warqla%2Cdz&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to warqla, dz
# Collecting data on city #60: castro, cl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=castro%2Ccl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #61: komsomolskiy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=komsomolskiy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #62: luderitz, na
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=luderitz%2Cna&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #63: provideniya, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=provideniya%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #64: khani, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=khani%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to khani, ru
# Collecting data on city #65: pangai, to
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=pangai%2Cto&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #66: yinchuan, cn
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=yinchuan%2Ccn&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #67: victoria, sc
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=victoria%2Csc&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #68: ust-kan, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ust-kan%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #69: solnechnyy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=solnechnyy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #70: souillac, mu
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=souillac%2Cmu&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #71: guerrero negro, mx
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=guerrero+negro%2Cmx&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #72: potgietersrus, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=potgietersrus%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to potgietersrus, za
# Collecting data on city #73: esperance, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=esperance%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #74: kaitangata, nz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kaitangata%2Cnz&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to kaitangata, nz
# Collecting data on city #75: hattiesburg, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hattiesburg%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #76: vestmannaeyjar, is
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vestmannaeyjar%2Cis&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #77: fort abbas, pk
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=fort+abbas%2Cpk&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #78: laela, tz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=laela%2Ctz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #79: mar del plata, ar
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mar+del+plata%2Car&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #80: ojinaga, mx
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ojinaga%2Cmx&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #81: okhotsk, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=okhotsk%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #82: jardim, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=jardim%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #83: glubokiy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=glubokiy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #84: el alto, pe
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=el+alto%2Cpe&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #85: tomatlan, mx
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tomatlan%2Cmx&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #86: cape town, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=cape+town%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #87: ushuaia, ar
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ushuaia%2Car&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #88: husavik, is
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=husavik%2Cis&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #89: rio tercero, ar
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=rio+tercero%2Car&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #90: zhigansk, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=zhigansk%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #91: rungata, ki
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=rungata%2Cki&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to rungata, ki
# Collecting data on city #92: vikhorevka, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vikhorevka%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #93: thompson, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=thompson%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #94: seoul, kr
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=seoul%2Ckr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #95: batagay-alyta, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=batagay-alyta%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #96: barrow, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=barrow%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #97: port hardy, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=port+hardy%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #98: kahului, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kahului%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #99: port alfred, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=port+alfred%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #100: ushtobe, kz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ushtobe%2Ckz&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to ushtobe, kz
# Collecting data on city #101: sinop, tr
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sinop%2Ctr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #102: notre-dame-du-lac, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=notre-dame-du-lac%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to notre-dame-du-lac, ca
# Collecting data on city #103: hofn, is
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hofn%2Cis&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #104: catia la mar, ve
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=catia+la+mar%2Cve&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #105: lorengau, pg
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=lorengau%2Cpg&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #106: kodiak, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kodiak%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #107: hamilton, bm
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hamilton%2Cbm&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #108: georgetown, sh
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=georgetown%2Csh&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #109: port elizabeth, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=port+elizabeth%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #110: veraval, in
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=veraval%2Cin&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #111: te anau, nz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=te+anau%2Cnz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #112: bonnyville, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bonnyville%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #113: ilulissat, gl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ilulissat%2Cgl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #114: hithadhoo, mv
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hithadhoo%2Cmv&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #115: balaipungut, id
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=balaipungut%2Cid&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #116: punta arenas, cl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=punta+arenas%2Ccl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #117: caravelas, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=caravelas%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #118: atuona, pf
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=atuona%2Cpf&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #119: adwa, et
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=adwa%2Cet&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to adwa, et
# Collecting data on city #120: arraial do cabo, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=arraial+do+cabo%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #121: nigde, tr
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=nigde%2Ctr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #122: baghdad, iq
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=baghdad%2Ciq&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #123: ereymentau, kz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ereymentau%2Ckz&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to ereymentau, kz
# Collecting data on city #124: hermanus, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hermanus%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #125: bheramara, bd
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bheramara%2Cbd&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #126: dikson, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=dikson%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #127: arauca, co
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=arauca%2Cco&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #128: chkalovsk, tj
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=chkalovsk%2Ctj&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to chkalovsk, tj
# Collecting data on city #129: mincivan, az
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mincivan%2Caz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #130: pevek, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=pevek%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #131: vao, nc
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vao%2Cnc&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #132: mgandu, tz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mgandu%2Ctz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #133: itoman, jp
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=itoman%2Cjp&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #134: kyzyl-suu, kg
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kyzyl-suu%2Ckg&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to kyzyl-suu, kg
# Collecting data on city #135: badarganj, bd
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=badarganj%2Cbd&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #136: lagunas, pe
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=lagunas%2Cpe&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #137: bredasdorp, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bredasdorp%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #138: bluff, nz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bluff%2Cnz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #139: sitka, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sitka%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #140: butaritari, ki
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=butaritari%2Cki&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #141: east london, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=east+london%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #142: attawapiskat, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=attawapiskat%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to attawapiskat, ca
# Collecting data on city #143: moundsville, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=moundsville%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #144: cockenzie, gb
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=cockenzie%2Cgb&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #145: jutai, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=jutai%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #146: bugaan, ph
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bugaan%2Cph&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #147: nyurba, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=nyurba%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #148: yilan, cn
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=yilan%2Ccn&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #149: ceres, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ceres%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #150: yulara, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=yulara%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #151: bambous virieux, mu
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bambous+virieux%2Cmu&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #152: tuatapere, nz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tuatapere%2Cnz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #153: jamestown, sh
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=jamestown%2Csh&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #154: bonthe, sl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bonthe%2Csl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #155: margate, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=margate%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #156: portlethen, gb
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=portlethen%2Cgb&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #157: san patricio, mx
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=san+patricio%2Cmx&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #158: amderma, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=amderma%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to amderma, ru
# Collecting data on city #159: bumba, cd
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bumba%2Ccd&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #160: gamba, ga
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=gamba%2Cga&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #161: mount isa, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mount+isa%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #162: vila velha, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vila+velha%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #163: kalaiya, np
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kalaiya%2Cnp&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to kalaiya, np
# Collecting data on city #164: cidreira, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=cidreira%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #165: cherskiy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=cherskiy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #166: carnarvon, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=carnarvon%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #167: klamath falls, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=klamath+falls%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #168: qaanaaq, gl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=qaanaaq%2Cgl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #169: kitale, ke
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kitale%2Cke&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #170: sofiysk, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sofiysk%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to sofiysk, ru
# Collecting data on city #171: chuy, uy
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=chuy%2Cuy&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #172: mahebourg, mu
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mahebourg%2Cmu&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #173: talcahuano, cl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=talcahuano%2Ccl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #174: maraa, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=maraa%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #175: sainte-rose, re
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sainte-rose%2Cre&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #176: muros, es
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=muros%2Ces&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #177: tateyama, jp
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tateyama%2Cjp&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #178: bethel, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bethel%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #179: upernavik, gl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=upernavik%2Cgl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #180: fortuna, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=fortuna%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #181: ukiah, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ukiah%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #182: luang prabang, la
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=luang+prabang%2Cla&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to luang prabang, la
# Collecting data on city #183: lulea, se
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=lulea%2Cse&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #184: san policarpo, ph
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=san+policarpo%2Cph&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #185: verkhnyaya inta, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=verkhnyaya+inta%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #186: zaysan, kz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=zaysan%2Ckz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #187: avarua, ck
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=avarua%2Cck&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #188: itacarambi, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=itacarambi%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #189: tucumcari, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tucumcari%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #190: vardo, no
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vardo%2Cno&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #191: hilo, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hilo%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #192: narsaq, gl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=narsaq%2Cgl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #193: khor, qa
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=khor%2Cqa&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to khor, qa
# Collecting data on city #194: tucuman, ar
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tucuman%2Car&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to tucuman, ar
# Collecting data on city #195: geisenheim, de
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=geisenheim%2Cde&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #196: malinyi, tz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=malinyi%2Ctz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #197: bengkalis, id
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bengkalis%2Cid&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to bengkalis, id
# Collecting data on city #198: tezu, in
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tezu%2Cin&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #199: tekeli, kz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tekeli%2Ckz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #200: claresholm, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=claresholm%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #201: bara, sd
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bara%2Csd&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to bara, sd
# Collecting data on city #202: saint george, bm
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=saint+george%2Cbm&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #203: zhigalovo, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=zhigalovo%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #204: serov, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=serov%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #205: koumac, nc
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=koumac%2Cnc&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #206: port-gentil, ga
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=port-gentil%2Cga&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #207: alta, no
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=alta%2Cno&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #208: lae, pg
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=lae%2Cpg&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #209: camopi, gf
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=camopi%2Cgf&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #210: sinnamary, gf
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sinnamary%2Cgf&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #211: tobias barreto, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tobias+barreto%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #212: gari, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=gari%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #213: mayo, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mayo%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #214: balkhash, kz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=balkhash%2Ckz&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to balkhash, kz
# Collecting data on city #215: tubuala, pa
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tubuala%2Cpa&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #216: bertoua, cm
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bertoua%2Ccm&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #217: mahbubabad, in
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=mahbubabad%2Cin&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #218: saint-pierre, pm
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=saint-pierre%2Cpm&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #219: lethem, gy
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=lethem%2Cgy&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to lethem, gy
# Collecting data on city #220: korla, cn
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=korla%2Ccn&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #221: kimbe, pg
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kimbe%2Cpg&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #222: ponta do sol, cv
# ...
# Collecting data on city #440: scarborough, tt
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=scarborough%2Ctt&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #441: beringovskiy, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=beringovskiy%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #442: fujin, cn
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=fujin%2Ccn&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #443: henties bay, na
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=henties+bay%2Cna&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to henties bay, na
# Collecting data on city #444: tambopata, pe
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tambopata%2Cpe&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #445: stolin, by
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=stolin%2Cby&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #446: takaka, nz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=takaka%2Cnz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #447: zhob, pk
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=zhob%2Cpk&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #448: ishigaki, jp
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ishigaki%2Cjp&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #449: petrivka, ua
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=petrivka%2Cua&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #450: benidorm, es
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=benidorm%2Ces&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #451: zhezkazgan, kz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=zhezkazgan%2Ckz&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to zhezkazgan, kz
# Collecting data on city #452: vostok, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vostok%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #453: sungai kolok, th
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sungai+kolok%2Cth&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to sungai kolok, th
# Collecting data on city #454: half moon bay, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=half+moon+bay%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #455: inhambane, mz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=inhambane%2Cmz&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #456: irece, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=irece%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #457: sao felix do xingu, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sao+felix+do+xingu%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #458: maicao, co
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=maicao%2Cco&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #459: quimper, fr
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=quimper%2Cfr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #460: along, in
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=along%2Cin&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #461: jacareacanga, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=jacareacanga%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #462: oriximina, br
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=oriximina%2Cbr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #463: hihifo, to
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hihifo%2Cto&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to hihifo, to
# Collecting data on city #464: leh, in
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=leh%2Cin&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #465: elizabeth city, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=elizabeth+city%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #466: vuktyl, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vuktyl%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #467: anadyr, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=anadyr%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #468: gorontalo, id
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=gorontalo%2Cid&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #469: freeport, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=freeport%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #470: cartagena, co
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=cartagena%2Cco&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #471: ballina, au
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=ballina%2Cau&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #472: pochutla, mx
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=pochutla%2Cmx&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to pochutla, mx
# Collecting data on city #473: nouakchott, mr
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=nouakchott%2Cmr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #474: sherlovaya gora, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sherlovaya+gora%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #475: bathsheba, bb
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bathsheba%2Cbb&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #476: aflu, dz
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=aflu%2Cdz&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to aflu, dz
# Collecting data on city #477: sinaloa, mx
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sinaloa%2Cmx&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to sinaloa, mx
# Collecting data on city #478: minas, uy
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=minas%2Cuy&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #479: varhaug, no
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=varhaug%2Cno&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #480: talnakh, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=talnakh%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #481: peniche, pt
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=peniche%2Cpt&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #482: naron, es
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=naron%2Ces&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #483: yirol, sd
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=yirol%2Csd&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to yirol, sd
# Collecting data on city #484: quesnel, ca
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=quesnel%2Cca&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #485: jiuquan, cn
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=jiuquan%2Ccn&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to jiuquan, cn
# Collecting data on city #486: angoram, pg
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=angoram%2Cpg&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #487: omboue, ga
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=omboue%2Cga&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #488: sorvag, fo
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sorvag%2Cfo&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to sorvag, fo
# Collecting data on city #489: avera, pf
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=avera%2Cpf&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to avera, pf
# Collecting data on city #490: dawlatabad, af
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=dawlatabad%2Caf&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to dawlatabad, af
# Collecting data on city #491: newport, us
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=newport%2Cus&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #492: bolungarvik, is
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bolungarvik%2Cis&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to bolungarvik, is
# Collecting data on city #493: christiana, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=christiana%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #494: libourne, fr
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=libourne%2Cfr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #495: nouadhibou, mr
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=nouadhibou%2Cmr&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #496: staryy saltiv, ua
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=staryy+saltiv%2Cua&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to staryy saltiv, ua
# Collecting data on city #497: serebryanyy bor, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=serebryanyy+bor%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #498: kruisfontein, za
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=kruisfontein%2Cza&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #499: esmeraldas, ec
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=esmeraldas%2Cec&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to esmeraldas, ec
# Collecting data on city #500: lata, sb
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=lata%2Csb&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to lata, sb
# Collecting data on city #501: vrangel, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=vrangel%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #502: cheremkhovo, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=cheremkhovo%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #503: hambantota, lk
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=hambantota%2Clk&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #504: dinsor, so
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=dinsor%2Cso&type=hour&start=1501188606&cnt=1&units=metric
# OpenWeather has no information on city, appending NaN to dinsor, so
# Collecting data on city #505: shache, cn
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=shache%2Ccn&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #506: sosnovo-ozerskoye, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=sosnovo-ozerskoye%2Cru&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #507: maniitsoq, gl
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=maniitsoq%2Cgl&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #508: finschhafen, pg
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=finschhafen%2Cpg&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #509: bad wildungen, de
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=bad+wildungen%2Cde&type=hour&start=1501188606&cnt=1&units=metric
# Collecting data on city #510: tilichiki, ru
# Requested URL: http://api.openweathermap.org/data/2.5/weather?appid=520a1531cd2ce1c453e489ffd47eb034&q=tilichiki%2Cru&type=hour&start=1501188606&cnt=1&units=metric

# %% [markdown]
# ### Creating the Dataframe
# All of the lists are pulled together into a dataframe.  Then printing out a CSV file.

# %%
weather_dict = {"Latitude": lat_data, "City": city_list, "Country": country_list, "Temperature": temp_data, 
                "Humidity": humid_data, "Cloudiness": cloud_data, "Wind Speed": wind_data, "Longitude": lng_data}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#          City  Cloudiness Country  Humidity  Latitude  Longitude  Temperature  \
# 0  oranjemund        32.0      na      95.0    -28.55     -28.55        16.59
# 1      garrel        90.0      de     100.0     52.95      52.95         5.37
# 2      halalo         NaN      wf       NaN       NaN        NaN          NaN
# 3    jinchang         0.0      cn      68.0     38.50      38.50       -12.79
# 4   tilichiki        44.0      ru      90.0     60.47      60.47       -17.41
#
#    Wind Speed
# 0        7.46
# 1        5.70
# 2         NaN
# 3        1.21
# 4        1.16

# %%
output = os.path.join('weatherPy_Hw6.csv')
weather_df.to_csv(output, header=True)

# %% [markdown]
# ### Drop cities not found, reset index
# Any city that is not in the OWM database will need to be deleted before running matplotlib/seaborn for analysis.  Interestingly, when applying formulas or manipulating the dataframe, a "SettingWithCopyWarning" kept popping up.  After some research, it is possible that manipulating a dataframe python makes a copy of the original, so when values are dropped and added, it compares the data to the original dataframe and notices that the indices don't match, so it throws a warning.  Unless the index is reset, the warning goes away.  Hence reset_index is needed.

# %%
weather_df = weather_df.dropna(axis=0, how='any')
weather_df = weather_df.reset_index(drop=True) #must reset index, or else run into SettingWithCopyWarning!!
weather_df.head()
# Out:
#              City  Cloudiness Country  Humidity  Latitude  Longitude  \
# 0      oranjemund        32.0      na      95.0    -28.55     -28.55
# 1          garrel        90.0      de     100.0     52.95      52.95
# 2        jinchang         0.0      cn      68.0     38.50      38.50
# 3       tilichiki        44.0      ru      90.0     60.47      60.47
# 4  saint-philippe         0.0      re      69.0    -21.36     -21.36
#
#    Temperature  Wind Speed
# 0        16.59        7.46
# 1         5.37        5.70
# 2       -12.79        1.21
# 3       -17.41        1.16
# 4        27.00        1.50

# %% [markdown]
# ### Applying formula - Convert to Fahrenheit
# While getting the 'SettingWithCopyWarning', I experimented with three different ways to calculate the temperature in fahrenheit.  I thought it had something to do with my function design, hence the replicates.  I ended up choosing the lambda function because it's new.  After new column was created with Fahrenheit temperatures.  The temperatures in celsius column was dropped and then columns were reorganized.

# %%
#Option #1:
Fahrenheit = lambda x: x*(9/5)+32
weather_df['Temperature (F)'] = weather_df['Temperature'].apply(Fahrenheit)
weather_df.head()

# Option #2:
# weather_df['Temperature (F)'] = weather_df.loc[:, 'Temperature']*(9/5)+32
# weather_df
# Option #3:
# weather_df['Temperature (F)'] = weather_df['Temperature'] *(9/5) +32
# weather_df
# Out:
#              City  Cloudiness Country  Humidity  Latitude  Longitude  \
# 0      oranjemund        32.0      na      95.0    -28.55     -28.55
# 1          garrel        90.0      de     100.0     52.95      52.95
# 2        jinchang         0.0      cn      68.0     38.50      38.50
# 3       tilichiki        44.0      ru      90.0     60.47      60.47
# 4  saint-philippe         0.0      re      69.0    -21.36     -21.36
#
#    Temperature  Wind Speed  Temperature (F)
# 0        16.59        7.46           61.862
# 1         5.37        5.70           41.666
# 2       -12.79        1.21            8.978
# 3       -17.41        1.16            0.662
# 4        27.00        1.50           80.600

# %%
weather_df.drop(['Temperature'], axis = 1, inplace = True)
weather_df = weather_df[['City', 'Country', 'Latitude', 'Longitude', 'Temperature (F)', 'Humidity', 'Wind Speed', 'Cloudiness']]
weather_df.head()
# Out:
#              City Country  Latitude  Longitude  Temperature (F)  Humidity  \
# 0      oranjemund      na    -28.55     -28.55           61.862      95.0
# 1          garrel      de     52.95      52.95           41.666     100.0
# 2        jinchang      cn     38.50      38.50            8.978      68.0
# 3       tilichiki      ru     60.47      60.47            0.662      90.0
# 4  saint-philippe      re    -21.36     -21.36           80.600      69.0
#
#    Wind Speed  Cloudiness
# 0        7.46        32.0
# 1        5.70        90.0
# 2        1.21         0.0
# 3        1.16        44.0
# 4        1.50         0.0

# %% [markdown]
# ## Scatter plots using Matplotlib/Seaborn libraries
# Created scatterplots for Humidity, Temperature, Cloudiness, and Wind Speed compared to Latitude.  Each chart is saved as PNG file and then shown.  The X and Y limits are defined according to the max and min values within the respective columns, then added some units to prevent points for getting cut off.

# %%
plt.scatter(weather_df['Latitude'], weather_df['Temperature (F)'], marker="o", 
            facecolors="red", edgecolors="black", alpha=0.95, s=30)
plt.ylim(weather_df['Temperature (F)'].min() - 20, weather_df['Temperature (F)'].max() + 20)
plt.xlim(weather_df['Latitude'].min()-15, weather_df['Latitude'].max()+15)

plt.title("Temperature (F) vs. Latitude on 7/27/2017")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

# %%
plt.savefig("Temperature_vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_df['Latitude'], weather_df['Humidity'], marker="o", 
            facecolors="red", edgecolors="black", alpha=0.95, s=30)
plt.ylim(weather_df['Humidity'].min() - 25, weather_df['Humidity'].max() + 25)
plt.xlim(weather_df['Latitude'].min()-15, weather_df['Latitude'].max()+15)

plt.title("Humidity vs. Latitude on 7/27/2017")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")

# %%
plt.savefig("Humidity_vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_df['Latitude'], weather_df['Wind Speed'], marker="o", 
            facecolors="red", edgecolors="black", alpha=0.95, s=30)
plt.ylim(weather_df['Wind Speed'].min() - 3, weather_df['Wind Speed'].max() + 3)
plt.xlim(weather_df['Latitude'].min()-15, weather_df['Latitude'].max()+15)

plt.title("Wind Speed vs. Latitude on 7/27/2017")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# %%
plt.savefig("WindSpeed_vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_df['Latitude'], weather_df['Cloudiness'], marker="o", 
            facecolors="red", edgecolors="black", alpha=0.95, s=30)
plt.ylim(weather_df['Cloudiness'].min() - 3, weather_df['Cloudiness'].max() + 3)
plt.xlim(weather_df['Latitude'].min()-15, weather_df['Latitude'].max()+15)

plt.title("Cloudiness vs. Latitude on 7/27/2017")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")

# %%
plt.savefig("Cloudiness_vs_Latitude.png")
plt.show()
